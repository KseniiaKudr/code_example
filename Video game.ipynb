# %%
import matplotlib.pyplot as plt

# %%
import pandas as pd
df = pd.read_csv('all_games.csv')

# %%
df
# Out:
#                                              name        platform  \
# 0            The Legend of Zelda: Ocarina of Time     Nintendo 64
# 1                        Tony Hawk's Pro Skater 2     PlayStation
# 2                             Grand Theft Auto IV   PlayStation 3
# 3                                     SoulCalibur       Dreamcast
# 4                             Grand Theft Auto IV        Xbox 360
# ...                                           ...             ...
# 18795                    Fast & Furious: Showdown        Xbox 360
# 18796                     Drake of the 99 Dragons            Xbox
# 18797  Afro Samurai 2: Revenge of Kuma Volume One   PlayStation 4
# 18798   Infestation: Survivor Stories (The War Z)              PC
# 18799         Leisure Suit Larry: Box Office Bust              PC
#
#              release_date                                            summary  \
# 0       November 23, 1998  As a young boy, Link is tricked by Ganondorf, ...
# ...

# %%
df1 = pd.read_csv('dataminer (1).csv')
df1.head()
df1.info()
df1['Initial  release date']
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 7 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0             51 non-null     int64
#  1   Title                  51 non-null     object
#  2   Sales                  51 non-null     object
#  3   Platform(s)            51 non-null     object
#  4   Initial  release date  51 non-null     object
#  5   Developer(s)           51 non-null     object
#  6   Publisher(s)           51 non-null     object
# dtypes: int64(1), object(6)
# memory usage: 2.9+ KB
# 0     November 18, 2011[b]
# 1       September 17, 2013
# 2       September 12, 2006
# 3        November 19, 2006
# 4        December 20, 2017
# 5       September 13, 1985
# 6        February 27, 1996
# 7         December 1, 2007
# 8            June 14, 1989
# 9                July 1980
# 10          April 10, 2008
# 11            May 29, 2014
# ...

# %%
from datetime import datetime
from datetime import date
today = date.today()
df1['Initial  release date'] = pd.to_datetime(df1['Initial  release date'], errors='coerce')
df1['year'] = df1['Initial  release date'].dt.year

# %%
df1
# Out:
#     Unnamed: 0                                             Title        Sales  \
# 0            0                                         Minecraft  200,000,000
# 1            1                                Grand Theft Auto V  130,000,000
# 2            2                                       Tetris (EA)  100,000,000
# 3            3                                        Wii Sports   82,900,000
# 4            4                     PlayerUnknown's Battlegrounds   60,000,000
# 5            5                                 Super Mario Bros.   48,240,000
# 6            6               Pokémon Red / Green / Blue / Yellow   47,520,000
# 7            7                          Wii Fit and Wii Fit Plus   43,800,000
# 8            8                                 Tetris (Nintendo)   43,000,000
# 9            9                                           Pac-Man   39,098,000
# 10          10                                    Mario Kart Wii   37,320,000
# ...

# %%
df_y_s = df1.groupby('year')['Sales'].sum().reset_index()
df_y_s
# Out:
#       year                                              Sales
# 0   1980.0                                         39,098,000
# 1   1981.0                                         20,000,000
# 2   1984.0                                         28,300,000
# 3   1985.0                                         48,240,000
# 4   1988.0                                         19,000,000
# 5   1989.0                               43,000,00018,370,500
# 6   1990.0                                         20,972,500
# 7   1991.0                               23,982,96020,000,000
# 8   1996.0                                         47,520,000
# 9   1999.0                                         29,490,000
# 10  2002.0                               22,540,00020,000,000
# 11  2004.0                               27,500,00017,830,000
# 12  2005.0                     23,960,00023,600,00019,010,000
# 13  2006.0  100,000,00082,900,00030,800,00028,020,00024,73...
# ...

# %%
fig = plt.figure(figsize = (10,10))
plt.bar(df_y_s['year'], df_y_s['Sales'])
plt.title('Global sales by year')
plt.xlabel('Year')
plt.ylabel('Numbers of copies, m.')
plt.xticks(rotation=90)
plt.show()

# %%
df2 = df1.groupby(['Developer(s)', 'year'])['Sales'].sum()
df2 = df2.reset_index()
df2['year'].max()
df3 = df2[df2['year']==2018]
df3
# Out:
#                         Developer(s)    year       Sales
# 0   Bandai Namco Studios / Sora Ltd.  2018.0  18,840,000
# 41                  Rockstar Studios  2018.0  31,000,000

# %%
fig = plt.figure(figsize = (10,10))
plt.bar(df2['Developer(s)'], df2['Sales'])
plt.title('Global sales by publisher')
plt.xlabel('Publisher')
plt.ylabel('Numbers of copies, m.')
plt.xticks(rotation=90)
plt.show()

# %%
data = pd.read_csv('vgsales.csv')
data.head()
# Out:
#    Rank                      Name Platform    Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37

# %%
df_y_s = data.groupby('Year')['Global_Sales'].sum().reset_index()
df_y_s
fig = plt.figure(figsize = (10,10))
plt.bar(df_y_s['Year'], df_y_s['Global_Sales'])
plt.title('Global sales by year')
plt.xlabel('Year')
plt.ylabel('Numbers of copies, m.')
plt.xticks(rotation=90)
plt.show()

# %%
df_pub = data.groupby('Year')['Name'].count().reset_index()
df_pub.head()
# Out:
#      Year  Name
# 0  1980.0     9
# 1  1981.0    46
# 2  1982.0    36
# 3  1983.0    17
# 4  1984.0    14

# %%
fig = plt.figure(figsize = (10,10))
plt.bar(df_pub['Year'],df_pub['Name'])
plt.title('A number of published games by year')
plt.xlabel('Year')
plt.ylabel('Number of games')
plt.xticks(rotation=90)
plt.show()
